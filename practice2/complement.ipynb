# %% [markdown]
# # 공부하면서 기록하는 부분입니다.

# %% [markdown]
# from nltk.corpus import stopwords를 사용하기 위해서는 다음과 같은 부분이 필요함.
#
#     import nltk
#     nltk.download('stopwords')

# %% [markdown]
# nltk.word_tokenize를 사용하려면 다음이 필요함
#
#     nltk.download('punkt')

# %% [markdown]
# NLTK
# - https://datascienceschool.net/view-notebook/8895b16a141749a9bb381007d52721c1/#NLTK-%EC%9E%90%EC%97%B0%EC%96%B4-%EC%B2%98%EB%A6%AC-%ED%8C%A8%ED%82%A4%EC%A7%80

# %% [markdown]
# enumerate
# - https://wikidocs.net/32#enumerate

# %% [markdown]
# keras
# - https://talkingaboutme.tistory.com/entry/DL-%ED%95%B4%EB%B3%B4%EB%A9%B4%EC%84%9C-%EB%B0%B0%EC%9A%B0%EB%8A%94-%EB%94%A5%EB%9F%AC%EB%8B%9D-ANN-%EA%B5%AC%ED%98%84-2?category=538748
# - https://talkingaboutme.tistory.com/entry/DL-%ED%95%B4%EB%B3%B4%EB%A9%B4%EC%84%9C-%EB%B0%B0%EC%9A%B0%EB%8A%94-%EB%94%A5%EB%9F%AC%EB%8B%9D-ANN-%EA%B5%AC%ED%98%84-3?category=538748
